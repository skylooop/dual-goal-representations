# %%
import ogbench

env, train_dataset, val_dataset = ogbench.make_env_and_datasets(
    dataset_name="antmaze-large-navigate-oraclerep-v0", add_info=True
)

# %%
train_dataset.keys()
# Out:
# dict_keys(['observations', 'actions', 'terminals', 'qpos', 'qvel', 'next_observations', 'oracle_reps'])
